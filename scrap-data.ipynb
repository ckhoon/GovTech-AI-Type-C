# %%
from webScraper import EthicalWebScraper

scraper = EthicalWebScraper("https://www.tp.edu.sg/landing/adult-learners.html")
documents = scraper.scrape_site(max_pages=50)

# %%
from webScraper import EthicalWebScraper

scraper = EthicalWebScraper("https://www.tp.edu.sg/landing/industry-partners.html")
documents = scraper.scrape_site(max_pages=50)

# %%
print(type(documents))
# Out:
# <class 'list'>

# %%
print(documents)
# Out:
# [{'url': 'https://www.tp.edu.sg/landing/industry-partners.html', 'content': 'Industry Partners | Temasek Polytechnic Industry Partners SHARE DIGITAL FILM & TELEVISION | SCHOOL OF DESIGN | TEMASEK POLYTECHNICS https://www.tp.edu.sg/ INNOVATE, CO-CREATE & ADD VALUE Work with us to Transform for Tomorrow and Create a Future of Growth. We identify your business needs, pull together the right resources and capabilities and reinvent your solutions with our end-to-end approach. Contact us LEVERAGING OUR CAPABILITIES IN mixed plastics technology, 3D printing-cementitious composites, carbon capture, utilisation & storage, advanced energy conversion & storage, smart power systems, energy sensors & analytics agriculture technology, aquaculture technology, future foods biosensors & microfluidics, flexible & wearable sensors, applied nutrition, Glycemic Index (GI) testing advanced manufacturing, robotics & automation, additive manufacturing Behavioural insights, applied research learnings, geront
# ...
